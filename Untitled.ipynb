# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importar base do sistema:

# %%
arquivo = pd.read_excel(r'C:\Users\L_SAR\Documents\Desenv\notas\base_alterdata_original.xlsx')

# Selecionando as colunas que serão utilizadas:
base_sistema = arquivo[['Nr. nota', 'Dt. emissão', 'Pessoa', 'CPF / CNPJ', 'Vl. faturamento', 'Emp. venda (Nm)', 'Emp. venda (nome curto)']]

# Apagando linhas em branco ou linhas de totais:
base_sistema = base_sistema.dropna(subset = ['Nr. nota'])


# Renomeando os campos para o padrão:
base_sistema = base_sistema.rename(columns = {'Nr. nota' : 'Nota'})
base_sistema = base_sistema.rename(columns = {'Dt. emissão' : 'Data'})
base_sistema = base_sistema.rename(columns = {'Pessoa' : 'Tomador'})
base_sistema = base_sistema.rename(columns = {'CPF / CNPJ' : 'CNPJ_CPF_Tomador'})
base_sistema = base_sistema.rename(columns = {'Vl. faturamento' : 'Valor'})
base_sistema = base_sistema.rename(columns = {'Emp. venda (Nm)' : 'Empresa'})
base_sistema = base_sistema.rename(columns = {'Emp. venda (nome curto)' : 'Unidade'})

# Convertendo tipos de campos:
#base_sistema['Nota'] = base_sistema['Nota'].astype(int)
base_sistema["Nota"] = base_sistema["Nota"].apply(np.int64)

# Valor total para verificar integridade do dataframe:
faturamento_base_sistema = base_sistema['Valor'].sum()

display(base_sistema)

print(faturamento_base_sistema)

base_sistema.dtypes
# Out:
#        Nota        Data                                            Tomador  \
# 0     16385  01/07/2022  MARIA CLARA ROSENO DA SILVA (113523)          ...
# 1     16386  01/07/2022  MARIA CLARA ROSENO DA SILVA (113523)          ...
# 2     16387  01/07/2022  SANDRA GOMES DE ANDRADE PROTASIO (113530)     ...
# 3     16388  01/07/2022  SANDRA GOMES DE ANDRADE PROTASIO (113530)     ...
# 4     16391  04/07/2022  JOSE IBIS TORRES (114087)                     ...
# ...     ...         ...                                                ...
# 3222    168  26/07/2022  CLAUDIO LUIS SILVA MACHADO (117546)           ...
# 3223    169  27/07/2022  RAMON DE OLIVEIRA GONCALEZ (117561)           ...
# 3224    170  27/07/2022  RAMON DE OLIVEIRA GONCALEZ (117561)           ...
# 3225    171  28/07/2022  MARLON RAMOS DE AQUINO (117603)               ...
# 3226    172  28/07/2022  MARLON RAMOS DE AQUINO (117603)               ...
#
#         CNPJ_CPF_Tomador   Valor  \
# ...

# %%
# Barra do Piraí

arquivo = pd.read_excel(r'C:\Users\L_SAR\Documents\Desenv\notas\barra_do_pirai\Barra_do_Pirai_Transguard.xlsx')

# Selecionando as colunas que serão utilizadas:
barra_pirai = arquivo[['Número', 'Emissão', 'Razão Social', 'Tomador', 'Serviço(R$)', 'Incidência']]

# Renomeando campo para que ele não seja renomeado duas vezes:
barra_pirai = barra_pirai.rename(columns = {'Tomador' : 'Tomador_temp'})

# Apagando linhas em branco ou linhas de totais:
barra_pirai = barra_pirai.dropna(subset = ['Número'])


# Renomeando os campos para o padrão:
barra_pirai = barra_pirai.rename(columns = {'Número' : 'Nota'})
barra_pirai = barra_pirai.rename(columns = {'Emissão' : 'Data'})
barra_pirai = barra_pirai.rename(columns = {'Razão Social' : 'Tomador'})
barra_pirai = barra_pirai.rename(columns = {'Tomador_temp' : 'CNPJ_CPF_Tomador'})
barra_pirai = barra_pirai.rename(columns = {'Serviço(R$)' : 'Valor'})
barra_pirai = barra_pirai.rename(columns = {'Incidência' : 'Unidade'})

# Criando coluna que falta:
barra_pirai['Empresa'] = 'Microsoft Corp Inc'

# Reordenando os campos:
barra_pirai = barra_pirai[['Nota', 'Data', 'Tomador', 'CNPJ_CPF_Tomador', 'Valor', 'Empresa','Unidade']]

# Convertendo tipos de campos:
barra_pirai['Data'] = barra_pirai['Data'].astype(str)


# Valor total para verificar integridade do dataframe:
faturamento_barra_pirai = barra_pirai['Valor'].sum()

#display(barra_pirai)

print(faturamento_barra_pirai)

barra_pirai.dtypes
# Out:
# 27246.61
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# Caicó Transguard

arquivo = pd.read_excel(r'C:\Users\L_SAR\Documents\Desenv\notas\caico\caico.xlsx')

# Selecionando as colunas que serão utilizadas:
caico = arquivo[['Número', 'Data', 'Tomador de Serviços', 'CPF/CNPJ', 'Valor Serviços R$']]

# Renomeando campo para que ele não seja renomeado duas vezes:
caico = caico.rename(columns = {'Data' : 'Data_caico'})

# Apagando linhas em branco ou linhas de totais:
caico = caico.dropna(subset = ['Número'])

# Renomeando os campos para o padrão:
caico = caico.rename(columns = {'Número' : 'Nota'})
caico = caico.rename(columns = {'Data_caico' : 'Data'})
caico = caico.rename(columns = {'Tomador de Serviços' : 'Tomador'})
caico = caico.rename(columns = {'CPF/CNPJ' : 'CNPJ_CPF_Tomador'})
caico = caico.rename(columns = {'Valor Serviços R$' : 'Valor'})

# Criando coluna que falta:
caico['Empresa'] = 'Microsoft Corp Inc'
caico['Unidade'] = 'Caico'

# Reordenando os campos:
caico = caico[['Nota', 'Data', 'Tomador', 'CNPJ_CPF_Tomador', 'Valor', 'Empresa', 'Unidade']]

# Convertendo tipos de campos:
caico["Nota"] = caico["Nota"].apply(np.int64)
caico['Data'] = caico['Data'].astype(str)


# Valor total para verificar integridade do dataframe:
faturamento_caico = caico['Valor'].sum()

#display(caico)

print(faturamento_caico)

caico.dtypes
# Out:
# 7229.720000000001
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# Caruaru Transguard, Pernambuco

arquivo = pd.read_excel(r'C:\Users\L_SAR\Documents\Desenv\notas\caruaru\Caruaru_Transguard.xlsx')

# Selecionando as colunas que serão utilizadas:
caruaru = arquivo[['ns2:Numero', 'ns2:DataEmissao', 'ns2:RazaoSocial5', 'ns2:Cpf', 'ns2:ValorServicos', 'ns2:Endereco6', 'ns2:NomeFantasia']]

# Apagando linhas em branco ou linhas de totais:
caruaru = caruaru.dropna(subset = ['ns2:Numero'])

# Renomeando os campos para o padrão:
caruaru = caruaru.rename(columns = {'ns2:Numero' : 'Nota'})
caruaru = caruaru.rename(columns = {'ns2:DataEmissao' : 'Data'})
caruaru = caruaru.rename(columns = {'ns2:RazaoSocial5' : 'Tomador'})
caruaru = caruaru.rename(columns = {'ns2:Cpf' : 'CNPJ_CPF_Tomador'})
caruaru = caruaru.rename(columns = {'ns2:ValorServicos' : 'Valor'})
caruaru = caruaru.rename(columns = {'ns2:Endereco6' : 'Empresa'})
caruaru = caruaru.rename(columns = {'ns2:NomeFantasia' : 'Unidade'})


# Convertendo tipos de campos:
caruaru["Nota"] = caruaru["Nota"].apply(np.int64)
caruaru['CNPJ_CPF_Tomador'] = caruaru['CNPJ_CPF_Tomador'].astype(str)
caruaru['Data'] = caruaru['Data'].astype(str)

# Valor total para verificar integridade do dataframe:
faturamento_caruaru = caruaru['Valor'].sum()

#display(caruaru)

print(faturamento_caruaru)

caruaru.dtypes
# Out:
# 35761.079999999994
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# Ceilandia Transguard

arquivo = pd.read_excel(r'C:\Users\L_SAR\Documents\Desenv\notas\ceilandia\Ceilandia_Transguard.xlsx')

# Selecionando as colunas que serão utilizadas:
ceilandia = arquivo[['Número', 'Data de emissão', 'Destinatário', 'Doc. Destinatário', 'Valor']]

# Renomeando campo para que ele não seja renomeado duas vezes:
ceilandia = ceilandia.rename(columns = {'Valor' : 'Valor_Total'})
ceilandia = ceilandia.rename(columns = {'Empresa' : 'Empresa_Nome'})

# Apagando linhas em branco ou linhas de totais:
ceilandia = ceilandia.dropna(subset = ['Número'])

# Renomeando os campos para o padrão:
ceilandia = ceilandia.rename(columns = {'Número' : 'Nota'})
ceilandia = ceilandia.rename(columns = {'Data de emissão' : 'Data'})
ceilandia = ceilandia.rename(columns = {'Destinatário' : 'Tomador'})
ceilandia = ceilandia.rename(columns = {'Doc. Destinatário' : 'CNPJ_CPF_Tomador'})
ceilandia = ceilandia.rename(columns = {'Valor_Total' : 'Valor'})
ceilandia = ceilandia.rename(columns = {'Empresa_Nome' : 'Empresa'})

# Criando coluna que falta:
ceilandia['Empresa'] = 'Microsoft Corp Inc'
ceilandia['Unidade'] = 'Ceilandia'

# Reordenando os campos:
ceilandia = ceilandia[['Nota', 'Data', 'Tomador', 'CNPJ_CPF_Tomador', 'Valor', 'Empresa', 'Unidade']]

# Convertendo tipos de campos:
ceilandia['Nota'] = ceilandia['Nota'].apply(np.int64)

# Valor total para verificar integridade do dataframe:
faturamento_ceilandia = ceilandia['Valor'].sum()

#display(base_sistema)

print(faturamento_ceilandia)

ceilandia.dtypes
# Out:
# 156902.43
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# Coite SPE

arquivo = pd.read_excel(r'C:\Users\L_SAR\Documents\Desenv\notas\coite\coite.xlsx')

# Selecionando as colunas que serão utilizadas:
coite = arquivo[['Nota', 'Emissão', 'Tomador', 'CNPJ/CPF Tomador', 'Valor Total']]

# Renomeando campo para que ele não seja renomeado duas vezes:
coite = coite.rename(columns = {'Nota' : 'Nota_coite'})
coite = coite.rename(columns = {'Tomador' : 'Tomador_coite'})

# Renomeando os campos para o padrão:
coite = coite.rename(columns = {'Nota_coite' : 'Nota'})
coite = coite.rename(columns = {'Emissão' : 'Data'})
coite = coite.rename(columns = {'Tomador_coite' : 'Tomador'})
coite = coite.rename(columns = {'CNPJ/CPF Tomador' : 'CNPJ_CPF_Tomador'})
coite = coite.rename(columns = {'Valor Total' : 'Valor'})

# Apagando linhas em branco ou linhas de totais:
coite = coite.dropna(subset = ['Nota'])

# Criando coluna que falta:
coite['Empresa'] = 'Microsoft Corp Inc'
coite['Unidade'] = 'Coite'

# Reordenando os campos:
coite = coite[['Nota', 'Data', 'Tomador', 'CNPJ_CPF_Tomador', 'Valor', 'Empresa', 'Unidade']]

# Convertendo tipos de campos:
coite['Data'] = coite['Data'].astype(str)

# Valor total para verificar integridade do dataframe:
faturamento_coite = coite['Valor'].sum()

#display(coite)

print(faturamento_coite)

coite.dtypes
# Out:
# 7489.469999999999
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# Cuiaba Nova

arquivo = pd.read_excel(r'C:\Users\L_SAR\Documents\Desenv\notas\cuiaba\cuiaba.xlsx')

# Selecionando as colunas que serão utilizadas:
cuiaba = arquivo[['Nº Doc.', 'Dt.Emissão', 'CPF/CNPJ Tomador', 'Valor Doc. (R$)']]

# Apagando linhas em branco ou linhas de totais:
cuiaba = cuiaba.dropna(subset = ['Nº Doc.'])


# Renomeando os campos para o padrão:
cuiaba = cuiaba.rename(columns = {'Nº Doc.' : 'Nota'})
cuiaba = cuiaba.rename(columns = {'Dt.Emissão' : 'Data'})
cuiaba = cuiaba.rename(columns = {'CPF/CNPJ Tomador' : 'CNPJ_CPF_Tomador'})
cuiaba = cuiaba.rename(columns = {'Valor Doc. (R$)' : 'Valor'})

# Criando coluna que falta:
cuiaba['Tomador'] = ''
cuiaba['Empresa'] = 'Microsoft Corp Inc'
cuiaba['Unidade'] = 'Cuiaba'

# Reordenando os campos:
cuiaba = cuiaba[['Nota', 'Data', 'Tomador', 'CNPJ_CPF_Tomador', 'Valor', 'Empresa','Unidade']]

# Convertendo tipos de campos:
cuiaba['Data'] = cuiaba['Data'].astype(str)


# Valor total para verificar integridade do dataframe:
faturamento_cuiaba = cuiaba['Valor'].sum()

#display(cuiaba)

print(faturamento_cuiaba)

cuiaba.dtypes
# Out:
# 371192.5
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# Itabuna Transguard Nordeste

arquivo = pd.read_excel(r'C:\Users\L_SAR\Documents\Desenv\notas\itabuna\Itabuna_Transguard_Nordeste.xlsx')

# Selecionando as colunas que serão utilizadas:
itabuna = arquivo[['Número', 'Emissão', 'Razão Social', 'Tomador', 'Total(R$)', 'Incidência']]

# Renomeando campo para que ele não seja renomeado duas vezes:
itabuna = itabuna.rename(columns = {'Tomador' : 'Tomador_itabuna'})

# Apagando linhas em branco ou linhas de totais:
itabuna = itabuna.dropna(subset = ['Número'])

# Renomeando os campos para o padrão:
itabuna = itabuna.rename(columns = {'Número' : 'Nota'})
itabuna = itabuna.rename(columns = {'Emissão' : 'Data'})
itabuna = itabuna.rename(columns = {'Razão Social' : 'Tomador'})
itabuna = itabuna.rename(columns = {'Tomador_itabuna' : 'CNPJ_CPF_Tomador'})
itabuna = itabuna.rename(columns = {'Total(R$)' : 'Valor'})
itabuna = itabuna.rename(columns = {'Incidência' : 'Unidade'})

# Criando coluna que falta:
itabuna['Empresa'] = 'Microsoft Corp Inc'

# Reordenando os campos:
itabuna = itabuna[['Nota', 'Data', 'Tomador', 'CNPJ_CPF_Tomador', 'Valor', 'Empresa','Unidade']]

# Convertendo tipos de campos:
itabuna['Nota'] = itabuna['Nota'].apply(np.int64)
itabuna['Data'] = itabuna['Data'].astype(str)


# Valor total para verificar integridade do dataframe:
faturamento_itabuna = itabuna['Valor'].sum()

#display(itabuna)

print(faturamento_itabuna)

itabuna.dtypes
# Out:
# 9629.0
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# Itaguai Transguard

arquivo = pd.read_excel(r"C:\Users\L_SAR\Documents\Desenv\notas\itaguai\itaguai_Tranguard.xlsx") # 

# Selecionando as colunas que serão utilizadas:
itaguai_trans = arquivo[["ns1:Numero", "ns1:DataEmissaoRps", "ns1:RazaoSocial4", "ns1:Cnpj", "ns1:ValorServicos", "ns1:RazaoSocial"]]

# Apagando linhas em branco:
itaguai_trans = itaguai_trans.dropna(subset=['ns1:Numero'])

# Criando campos adicionais:
itaguai_trans["Unidade"] = "Itaguai_Transguard"

# Renomeando os campos para o padrão:
itaguai_trans = itaguai_trans.rename(columns={"ns1:Numero": "Nota"})
itaguai_trans = itaguai_trans.rename(columns={"ns1:DataEmissaoRps": "Data"})
itaguai_trans = itaguai_trans.rename(columns={"ns1:RazaoSocial4": "Tomador"})
itaguai_trans = itaguai_trans.rename(columns={"ns1:Cnpj": "CNPJ_CPF_Tomador"})
itaguai_trans = itaguai_trans.rename(columns={"ns1:ValorServicos": "Valor"})
itaguai_trans = itaguai_trans.rename(columns={"ns1:RazaoSocial": "Empresa"})

# Reordenando colunas:
itaguai_trans = itaguai_trans[['Nota','Data','Tomador','CNPJ_CPF_Tomador','Valor', 'Empresa', 'Unidade']]

# Convertendo tipos de campos:
itaguai_trans["Nota"] = itaguai_trans["Nota"].apply(np.int64) # Converte INT64
itaguai_trans["Data"] = itaguai_trans["Data"].astype(str)
itaguai_trans["CNPJ_CPF_Tomador"] = itaguai_trans["CNPJ_CPF_Tomador"].astype(str)


# Valor total:
faturamento_itaguai_trans = itaguai_trans["Valor"].sum()

#display(itaguai_trans)

print ("Total:", faturamento_itaguai_trans)

itaguai_trans.dtypes
# Out:
# Total: 28776.54
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# Itaperuna Nova Rl

arquivo = pd.read_excel(r"C:\Users\L_SAR\Documents\Desenv\notas\itaperuna\ITAPERUNA.xlsx") # 

# Selecionando as colunas que serão utilizadas:
itaperuna_nova_rl = arquivo[["Numero", "DataEmissao", "RazaoSocial13", "Cpf", "ValorServicos", "RazaoSocial"]]

# Apagando linhas em branco:
itaperuna_nova_rl = itaperuna_nova_rl.dropna(subset=['Numero'])

# Criando campos adicionais:
itaperuna_nova_rl["Unidade"] = "Itaperuna Nova RL"

# Renomeando os campos para o padrão:
itaperuna_nova_rl = itaperuna_nova_rl.rename(columns={"Numero": "Nota"})
itaperuna_nova_rl = itaperuna_nova_rl.rename(columns={"DataEmissao": "Data"})
itaperuna_nova_rl = itaperuna_nova_rl.rename(columns={"RazaoSocial13": "Tomador"})
itaperuna_nova_rl = itaperuna_nova_rl.rename(columns={"Cpf": "CNPJ_CPF_Tomador"})
itaperuna_nova_rl = itaperuna_nova_rl.rename(columns={"ValorServicos": "Valor"})
itaperuna_nova_rl = itaperuna_nova_rl.rename(columns={"RazaoSocial": "Empresa"})

# Reordenando colunas:
itaperuna_nova_rl = itaperuna_nova_rl[['Nota','Data','Tomador','CNPJ_CPF_Tomador','Valor', 'Empresa', 'Unidade']]

# Convertendo tipos de campos:
itaperuna_nova_rl["Data"] = itaperuna_nova_rl["Data"].astype(str)
itaperuna_nova_rl["CNPJ_CPF_Tomador"] = itaperuna_nova_rl["CNPJ_CPF_Tomador"].astype(str)

# Valor total:
faturamento_itaperuna_nova_rl = itaperuna_nova_rl["Valor"].sum()

#display(itaperuna_nova_rl)

print ("Total:", faturamento_itaperuna_nova_rl)

itaperuna_nova_rl.dtypes
# Out:
# Total: 4247.96
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# Maceió Transguard

arquivo = pd.read_excel(r"C:\Users\L_SAR\Documents\Desenv\notas\maceio\Maceio_Transguard.xlsx") # 

# Selecionando as colunas que serão utilizadas:
maceio_trans = arquivo[["NUMERO DOCUMENTO", "DATA EMISSAO", "RAZAO SOCIAL TOMADOR", "CNPJ/CPF TOMADOR", "VALOR DO SERVICO", "RAZAO SOCIAL PRESTADOR", "LOCAL DA PRESTAÇÃO"]]

# Apagando linhas em branco:
maceio_trans = maceio_trans.dropna(subset=['NUMERO DOCUMENTO'])

# Renomeando os campos para o padrão:
maceio_trans = maceio_trans.rename(columns={"NUMERO DOCUMENTO": "Nota"})
maceio_trans = maceio_trans.rename(columns={"DATA EMISSAO": "Data"})
maceio_trans = maceio_trans.rename(columns={"RAZAO SOCIAL TOMADOR": "Tomador"})
maceio_trans = maceio_trans.rename(columns={"CNPJ/CPF TOMADOR": "CNPJ_CPF_Tomador"})
maceio_trans = maceio_trans.rename(columns={"VALOR DO SERVICO": "Valor"})
maceio_trans = maceio_trans.rename(columns={"RAZAO SOCIAL PRESTADOR": "Empresa"})
maceio_trans = maceio_trans.rename(columns={"LOCAL DA PRESTAÇÃO": "Unidade"})

# Convertendo tipos de campos:
maceio_trans["Nota"] = maceio_trans["Nota"].apply(np.int64) # Converte INT64
maceio_trans["CNPJ_CPF_Tomador"] = maceio_trans["CNPJ_CPF_Tomador"].astype(str)

# Valor total:
faturamento_maceio_trans = maceio_trans["Valor"].sum()

#display(maceio_trans)

print ("Total:", faturamento_maceio_trans)

maceio_trans.dtypes
# Out:
# Total: 67462.33
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# Magé - Nova RL

arquivo = pd.read_excel(r"C:\Users\L_SAR\Documents\Desenv\notas\mage_nova_rl\Mage_Nova_RL.xls")

#--------------------------------------------RESOLVENDO PROBLEMA DO CAMPO TOMADOR (JUNTO COM CPF)--------------------------------------------------
# Apagando linhas em branco para poder trabalhar o campo:
arquivo = arquivo.dropna(subset=['N° da Nota'])

# Fazer slice do campo 'Tomador' para compor o campo CPF:
tomador_temp = arquivo['Tomador'].str.slice(start = 16)
cpf_temp = arquivo['Tomador'].str.slice(start = 1, stop = 12)

# Criando campos para separar os dados:
arquivo['tomador_temp'] = (tomador_temp)
arquivo['cpf_temp'] = (cpf_temp)

#display(arquivo)
#--------------------------------------------------------------------------------------------------------------------------------------------------

# Selecionando as colunas que serão utilizadas:
mage_nova_rl = arquivo[["N° da Nota", "Data Emissão", "tomador_temp", "cpf_temp", "Valor do Serviço", "Local Incidência"]]

# Apagando linhas em branco:
mage_nova_rl = mage_nova_rl.dropna(subset=['N° da Nota'])

# Criando campos adicionais:
mage_nova_rl["Empresa"] = 'Nova RL'

# Renomeando os campos para o padrão:
mage_nova_rl = mage_nova_rl.rename(columns={"N° da Nota": "Nota"})
mage_nova_rl = mage_nova_rl.rename(columns={"Data Emissão": "Data"})
mage_nova_rl = mage_nova_rl.rename(columns={"tomador_temp": "Tomador"})
mage_nova_rl = mage_nova_rl.rename(columns={"cpf_temp": "CNPJ_CPF_Tomador"})
mage_nova_rl = mage_nova_rl.rename(columns={"Valor do Serviço": "Valor"})
mage_nova_rl = mage_nova_rl.rename(columns={"Local Incidência": "Unidade"})

# Reordenando colunas:
mage_nova_rl = mage_nova_rl[['Nota','Data','Tomador','CNPJ_CPF_Tomador','Valor', 'Empresa', 'Unidade']]

# Convertendo tipos de campos:
mage_nova_rl["Data"] = mage_nova_rl["Data"].astype(str)

# Valor total:
faturamento_mage_nova_rl = mage_nova_rl["Valor"].sum()

#display(mage_nova_rl)

print ("Total:", faturamento_mage_nova_rl)

mage_nova_rl.dtypes
# Out:
# Total: 14821.02
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# Magé Transguard

arquivo = pd.read_excel(r"C:\Users\L_SAR\Documents\Desenv\notas\mage_transguard\Mage_Transguard.xlsx") # 

#--------------------------------------------RESOLVENDO PROBLEMA DO CAMPO TOMADOR (JUNTO COM CPF)--------------------------------------------------
# Apagando linhas em branco para poder trabalhar o campo:
arquivo = arquivo.dropna(subset=['N° da Nota'])

# Fazer slice do campo 'Tomador' para compor o campo CPF:
tomador_temp = arquivo['Tomador'].str.slice(start = 16)
cpf_temp = arquivo['Tomador'].str.slice(start = 1, stop = 12)

# Criando campos para separar os dados:
arquivo['tomador_temp'] = (tomador_temp)
arquivo['cpf_temp'] = (cpf_temp)

#display(arquivo)
#--------------------------------------------------------------------------------------------------------------------------------------------------

# Selecionando as colunas que serão utilizadas:
mage_transguard = arquivo[["N° da Nota", "Data Emissão", "tomador_temp", "cpf_temp", "Valor do Serviço", "Local Incidência"]]

# Apagando linhas em branco:
mage_transguard = mage_transguard.dropna(subset=['N° da Nota'])

# Criando campos adicionais:
mage_transguard["Empresa"] = "Transguard"

# Renomeando os campos para o padrão:
mage_transguard = mage_transguard.rename(columns={"N° da Nota": "Nota"})
mage_transguard = mage_transguard.rename(columns={"Data Emissão": "Data"})
mage_transguard = mage_transguard.rename(columns={"tomador_temp": "Tomador"})
mage_transguard = mage_transguard.rename(columns={"cpf_temp": "CNPJ_CPF_Tomador"})
mage_transguard = mage_transguard.rename(columns={"Valor do Serviço": "Valor"})
mage_transguard = mage_transguard.rename(columns={"Local Incidência": "Unidade"})

# Reordenando colunas:
mage_transguard = mage_transguard[['Nota','Data','Tomador','CNPJ_CPF_Tomador','Valor', 'Empresa', 'Unidade']]

# Convertendo tipos de campos:
mage_transguard["Data"] = mage_transguard["Data"].astype(str)

# Valor total:
faturamento_mage_transguard = mage_transguard["Valor"].sum()

#display(mage_transguard)

print ("Total:", faturamento_mage_transguard)

mage_transguard.dtypes
# Out:
# Total: 17552.36
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# Mossoró Transguard

arquivo = pd.read_excel(r"C:\Users\L_SAR\Documents\Desenv\notas\mossoro_transguard\Mossoro_Transguard_DUPLICADOS.xlsx")

#--------------------------------------------Ajustando Duplicidade--------------------------------------------------
# Renomeando o campo antes de selecionar:
#arquivo = arquivo.rename(columns = {'ValorServicos' : 'Valor'})

# Apagando as linhas duplicadas:
#arquivo = arquivo.sort_values('RazaoSocial3', ascending = False)
arquivo = arquivo.drop_duplicates(subset = 'ns1:Numero', keep = 'first')

#-------------------------------------------------------------------------------------------------------------------
# Selecionando as colunas que serão utilizadas:
mossoro_trans = arquivo[["ns1:Numero","ns1:DataEmissaoRps", "RazaoSocial3", "Cpf", "ValorServicos", "RazaoSocial"]]

# Apagando linhas em branco:
mossoro_trans = mossoro_trans.dropna(subset=['ns1:Numero'])

# Criando campos adicionais:
mossoro_trans["Unidade"] = "Mossoro"

# Renomeando os campos para o padrão:
mossoro_trans = mossoro_trans.rename(columns={"ns1:Numero": "Nota"})
mossoro_trans = mossoro_trans.rename(columns={"ns1:DataEmissaoRps": "Data"})
mossoro_trans = mossoro_trans.rename(columns={"RazaoSocial3": "Tomador"})
mossoro_trans = mossoro_trans.rename(columns={"Cpf": "CNPJ_CPF_Tomador"})
mossoro_trans = mossoro_trans.rename(columns={"ValorServicos": "Valor"})
mossoro_trans = mossoro_trans.rename(columns={"RazaoSocial": "Empresa"})

# Reordenando colunas:
mossoro_trans = mossoro_trans[['Nota','Data','Tomador','CNPJ_CPF_Tomador','Valor', 'Empresa', 'Unidade']]

# Convertendo tipos de campos:
mossoro_trans["Nota"] = mossoro_trans["Nota"].apply(np.int64) # Converte INT64
mossoro_trans["Data"] = mossoro_trans["Data"].astype(str)
mossoro_trans["CNPJ_CPF_Tomador"] = mossoro_trans["CNPJ_CPF_Tomador"].astype(str)

# Valor total:
faturamento_mossoro_trans = mossoro_trans["Valor"].sum()

#display(mossoro_trans)

print ("Total:", faturamento_mossoro_trans)

mossoro_trans.dtypes
# Out:
# Total: 24716.72
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# Natal - Transguard

arquivo = pd.read_excel(r"C:\Users\L_SAR\Documents\Desenv\notas\natal_transguard\Natal - Transguard.xlsx")  

# Transformando a primeira linha em cabeçalho:
arquivo.columns = arquivo.iloc[0]

# Selecionando as colunas que serão utilizadas:
natal_trans = arquivo[["N° Nota", "Emissão", "Tomador", "Serviço(R$)", "Prestador"]]

# Apagando linhas em branco:
natal_trans = natal_trans.dropna(subset=['N° Nota'])

# Criando campos adicionais:
natal_trans["Unidade"] = "Natal - Transguard"
natal_trans["CNPJ_CPF_Tomador"] = ""
    
# Renomeando os campos para o padrão:
natal_trans = natal_trans.rename(columns={"N° Nota": "Nota"})
natal_trans = natal_trans.rename(columns={"Emissão": "Data"})
natal_trans = natal_trans.rename(columns={"Tomador": "Tomador"})
natal_trans = natal_trans.rename(columns={"Serviço(R$)": "Valor"})
natal_trans = natal_trans.rename(columns={"Prestador": "Empresa"})

# Reordenando colunas:
natal_trans = natal_trans[['Nota','Data','Tomador','CNPJ_CPF_Tomador','Valor', 'Empresa', 'Unidade']]

#--------------------------------------------Resolvendo cabeçalho repetido--------------------------------------------------

# Pegando os nomes das colunas para indexar:
index_nomes = natal_trans[natal_trans["Nota"] == "N° Nota"].index

# Apagando a linha idexada:
natal_trans.drop(index_nomes, inplace = True)

#-------------------------------------------------------------------------------------------------------------------

# Convertendo tipos de campos:
natal_trans["Nota"] = natal_trans["Nota"].apply(np.int64) # Converte INT64
natal_trans["Valor"] = natal_trans["Valor"].astype(float)

# Valor total:
faturamento_natal_trans = natal_trans["Valor"].sum()

#display(natal_trans)

print ("Total:", faturamento_natal_trans)

natal_trans.dtypes
# Out:
# Total: 33943.740000000005
# 0
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# Petrolina RL

arquivo = pd.read_excel(r"C:\Users\L_SAR\Documents\Desenv\notas\petrolina_rl\Petrolina_RL.xlsx")  

#----------------------------------------------------SEPARAR CPF E TOMADOR----------------------------------------------------

# Apagando linhas em branco:
arquivo = arquivo.dropna(subset = "Número")

# Fazendo slice do campo tomador para compor o campo CPF:
tomador_temp = arquivo["Tomador"].str.slice(start = 17)
cpf_temp = arquivo["Tomador"].str.slice(start = 0, stop = 14)

# Criando campos para separar os dados:
arquivo["Tomador"] = (tomador_temp)
arquivo["CNPJ_CPF_Tomador"] = (cpf_temp)

#-----------------------------------------------------------------------------------------------------------------------------

# Selecionando as colunas que serão utilizadas:
petrolina_rl = arquivo[["Número", "Emissão", "Tomador", "CNPJ_CPF_Tomador", "Valor"]]

# Criando campos adicionais:
petrolina_rl["Empresa"] = "Petrolina RL"
petrolina_rl["Unidade"] = "Petrolina RL"

# Renomeando os campos para o padrão:
petrolina_rl = petrolina_rl.rename(columns={"Número": "Nota"})
petrolina_rl = petrolina_rl.rename(columns={"Emissão": "Data"})
#petrolina_rl = petrolina_rl.rename(columns={"": "Tomador"})
#petrolina_rl = petrolina_rl.rename(columns={"": "CNPJ_CPF_Tomador"})
petrolina_rl = petrolina_rl.rename(columns={"Valor": "Valor"})

# Reordenando colunas:
petrolina_rl = petrolina_rl[['Nota','Data',"Tomador", "CNPJ_CPF_Tomador",'Valor', 'Empresa', 'Unidade']]

# Convertendo tipos de campos:
#petrolina_rl[""] = petrolina_rl[""].apply(np.int64) # Converte INT64
petrolina_rl["Data"] = petrolina_rl["Data"].astype(str)

# Valor total:
faturamento_petrolina_rl = petrolina_rl["Valor"].sum()

#display(petrolina_rl)

print ("Total:", faturamento_petrolina_rl)

petrolina_rl.dtypes
# Out:
# Total: 1635.83
# C:\Users\L_SAR\AppData\Local\Temp\ipykernel_13500\3032514744.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   petrolina_rl["Empresa"] = "Petrolina RL"
# C:\Users\L_SAR\AppData\Local\Temp\ipykernel_13500\3032514744.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   petrolina_rl["Unidade"] = "Petrolina RL"
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# ...

# %%
# Salgueiro - Transguard

arquivo = pd.read_excel(r"C:\Users\L_SAR\Documents\Desenv\notas\salgueiro\Salgueiro_Transguard.xls") # 

# Selecionando as colunas que serão utilizadas:
salgueiro_trans = arquivo[["Numero", "Data", "Nome tomador", "Doc tomador", "Valor", "Razao social prestador", "Cidade"]]

# Apagando linhas em branco:
salgueiro_trans = salgueiro_trans.dropna(subset=['Numero'])

# Renomeando os campos para o padrão:
salgueiro_trans = salgueiro_trans.rename(columns={"Numero": "Nota"})
salgueiro_trans = salgueiro_trans.rename(columns={"Data": "Data"})
salgueiro_trans = salgueiro_trans.rename(columns={"Nome tomador": "Tomador"})
salgueiro_trans = salgueiro_trans.rename(columns={"Doc tomador": "CNPJ_CPF_Tomador"})
salgueiro_trans = salgueiro_trans.rename(columns={"Valor": "Valor"})
salgueiro_trans = salgueiro_trans.rename(columns={"Razao social prestador": "Empresa"})
salgueiro_trans = salgueiro_trans.rename(columns={"Cidade": "Unidade"})

# Convertendo tipos de campos:
salgueiro_trans["Nota"] = salgueiro_trans["Nota"].apply(np.int64) # Converte INT64
salgueiro_trans["CNPJ_CPF_Tomador"] = salgueiro_trans["CNPJ_CPF_Tomador"].astype(str)

# Valor total:
faturamento_salgueiro_trans = salgueiro_trans["Valor"].sum()

#display(salgueiro_trans)

print ("Total:", faturamento_salgueiro_trans)

salgueiro_trans.dtypes
# Out:
# Total: 41247.240000000005
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# São Caetano - Nova RL

arquivo = pd.read_excel(r"C:\Users\L_SAR\Documents\Desenv\notas\sao_caetano_nova_rl\Sao_Caetano - Nova RL.xlsx")  

# Selecionando as colunas que serão utilizadas:
sao_caetano_nova_rl = arquivo[["NF INI", "DIA", "NOME DA RAZÃO SOCIAL", "CNPJ/CPF", "VAL. FATURADO"]]

# Apagando linhas em branco:
sao_caetano_nova_rl = sao_caetano_nova_rl.dropna(subset=['NF INI'])

# Criando campos adicionais:
sao_caetano_nova_rl["Empresa"] = "São Caetano - Nova RL"
sao_caetano_nova_rl["Unidade"] = "São Caetano - Nova RL"

# Renomeando os campos para o padrão:
sao_caetano_nova_rl = sao_caetano_nova_rl.rename(columns={"NF INI": "Nota"})
sao_caetano_nova_rl = sao_caetano_nova_rl.rename(columns={"DIA": "DIA_temp"})
sao_caetano_nova_rl = sao_caetano_nova_rl.rename(columns={"NOME DA RAZÃO SOCIAL": "Tomador"})
sao_caetano_nova_rl = sao_caetano_nova_rl.rename(columns={"CNPJ/CPF": "CNPJ_CPF_Tomador"})
sao_caetano_nova_rl = sao_caetano_nova_rl.rename(columns={"VAL. FATURADO": "Valor"})

#-------------------------------------------------Resolvendo problema campo Data----------------------------------------------
# Convertendo tipos de campos:
sao_caetano_nova_rl["DIA_temp"] = sao_caetano_nova_rl["DIA_temp"].astype(str)

# Criando variável mes e ano:
sao_caetano_nova_rl['Mes_ano'] = '/07/2022'

# Concatenando a coluna DIA com a coluna Mes_ano:
sao_caetano_nova_rl['Data'] = sao_caetano_nova_rl['DIA_temp'] + sao_caetano_nova_rl['Mes_ano']

#-----------------------------------------------------------------------------------------------------------------------------

# Reordenando colunas:
sao_caetano_nova_rl = sao_caetano_nova_rl[['Nota', 'Data', 'Tomador','CNPJ_CPF_Tomador','Valor', 'Empresa', 'Unidade']]

# Valor total:
faturamento_sao_caetano_nova_rl = sao_caetano_nova_rl["Valor"].sum()

#display(sao_caetano_nova_rl)

print ("Total:", faturamento_sao_caetano_nova_rl)

sao_caetano_nova_rl.dtypes
# Out:
# Total: 29833.859999999997
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# São Gonçalo Transguard

arquivo = pd.read_excel(r"C:\Users\L_SAR\Documents\Desenv\notas\sao_goncalo\Sao_Goncalo_Transguard.xlsx") # 

# Selecionando as colunas que serão utilizadas:
sao_goncalo_trans = arquivo[["Número", "Data Emissão", "Tomador", "CNPJ Tomador", "Vl. NF."]]

# Apagando linhas em branco:
sao_goncalo_trans = sao_goncalo_trans.dropna(subset=['Número'])

# Criando campos adicionais:
sao_goncalo_trans["Empresa"] = 'Microsoft Corp Inc'
sao_goncalo_trans["Unidade"] = "SÃO GONÇALO - RJ"

# Renomeando os campos para o padrão:
sao_goncalo_trans = sao_goncalo_trans.rename(columns={"Número": "Nota"})
sao_goncalo_trans = sao_goncalo_trans.rename(columns={"Data Emissão": "Data"})
sao_goncalo_trans = sao_goncalo_trans.rename(columns={"Tomador": "Tomador"})
sao_goncalo_trans = sao_goncalo_trans.rename(columns={"CNPJ Tomador": "CNPJ_CPF_Tomador"})
sao_goncalo_trans = sao_goncalo_trans.rename(columns={"Vl. NF.": "Valor"})

# Reordenando colunas:
sao_goncalo_trans = sao_goncalo_trans[['Nota','Data','Tomador','CNPJ_CPF_Tomador','Valor', 'Empresa', 'Unidade']]

# Convertendo tipos de campos:
sao_goncalo_trans["Nota"] = sao_goncalo_trans["Nota"].apply(np.int64) # Converte INT64

# Valor total:
faturamento_sao_goncalo_trans = sao_goncalo_trans["Valor"].sum()

#display(sao_goncalo_trans)

print ("Total:", faturamento_sao_goncalo_trans)

sao_goncalo_trans.dtypes
# Out:
# Total: 202388.71999999997
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# Senhor do Bonfim

arquivo = pd.read_excel(r"C:\Users\L_SAR\Documents\Desenv\notas\senhor_do_bonfim\Senhor_do_bonfim_Rodando_SPE.xlsx") # 

# Selecionando as colunas que serão utilizadas:
senhor_do_bonfim = arquivo[["Número", "Emissão", "Razão Social", "Tomador", "Total(R$)", "Incidência"]]

# Renomeando campo para que ele não seja renomeado duas vezes:
senhor_do_bonfim = senhor_do_bonfim.rename(columns = {'Tomador' : 'Tomador_senhor_do_bonfim'})

# Apagando linhas em branco:
senhor_do_bonfim = senhor_do_bonfim.dropna(subset=['Número'])

# Criando campos adicionais:
senhor_do_bonfim["Empresa"] = 'Microsoft Corp Inc'

# Renomeando os campos para o padrão:
senhor_do_bonfim = senhor_do_bonfim.rename(columns={"Número": "Nota"})
senhor_do_bonfim = senhor_do_bonfim.rename(columns={"Emissão": "Data"})
senhor_do_bonfim = senhor_do_bonfim.rename(columns={"Razão Social": "Tomador"})
senhor_do_bonfim = senhor_do_bonfim.rename(columns={"Tomador_senhor_do_bonfim": "CNPJ_CPF_Tomador"})
senhor_do_bonfim = senhor_do_bonfim.rename(columns={"Total(R$)": "Valor"})
senhor_do_bonfim = senhor_do_bonfim.rename(columns={"Incidência": "Unidade"})

# Reordenando colunas:
senhor_do_bonfim = senhor_do_bonfim[['Nota','Data','Tomador','CNPJ_CPF_Tomador','Valor', 'Empresa', 'Unidade']]

# Convertendo tipos de campos:
senhor_do_bonfim["Data"] = senhor_do_bonfim["Data"].astype(str)

# Valor total:
faturamento_senhor_do_bonfim = senhor_do_bonfim["Valor"].sum()

#display(senhor_do_bonfim)

print ("Total:", faturamento_senhor_do_bonfim)

senhor_do_bonfim.dtypes
# Out:
# Total: 8840.33
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# Serra Talhada

arquivo = pd.read_excel(r"C:\Users\L_SAR\Documents\Desenv\notas\serra_talhada\Serra_Talhada.xlsx")  

# Selecionando as colunas que serão utilizadas:
serra_talhada = arquivo[["NF", "Data", "N1", "N2", "N3", "CNPJ", "Valor", "Empresa", "Unidade"]]

# Apagando linhas em branco:
serra_talhada = serra_talhada.dropna(subset=['NF'])

# Renomeando os campos para o padrão:
serra_talhada = serra_talhada.rename(columns={"NF": "Nota"})
serra_talhada = serra_talhada.rename(columns={"Data": "Data"})
serra_talhada = serra_talhada.rename(columns={"CNPJ": "CNPJ_CPF_Tomador"})
serra_talhada = serra_talhada.rename(columns={"Valor": "Valor"})
serra_talhada = serra_talhada.rename(columns={"Empresa": "Empresa"})
serra_talhada = serra_talhada.rename(columns={"Unidade": "Unidade"})

#----------------------------------------------Resolvendo problema campo Tomador----------------------------------------------
# Convertendo tipos de campos:
#serra_talhada["DIA_temp"] = serra_talhada["DIA_temp"].astype(str)

# Criando variável mes e ano:
serra_talhada['Tomador'] = serra_talhada['N1'] + ' ' + serra_talhada['N2'] + ' ' + serra_talhada['N3']

#-----------------------------------------------------------------------------------------------------------------------------

# Reordenando colunas:
serra_talhada = serra_talhada[['Nota','Data','Tomador','CNPJ_CPF_Tomador','Valor', 'Empresa', 'Unidade']]

# Convertendo tipos de campos:
serra_talhada["Nota"] = serra_talhada["Nota"].apply(np.int64) # Converte INT64
serra_talhada["Data"] = serra_talhada["Data"].astype(str)
serra_talhada["CNPJ_CPF_Tomador"] = serra_talhada["CNPJ_CPF_Tomador"].astype(str)

# Valor total:
faturamento_serra_talhada = serra_talhada["Valor"].sum()

#display(serra_talhada)

print ("Total:", faturamento_serra_talhada)

serra_talhada.dtypes
# Out:
# Total: 6937.8
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# Tanguá Nova RL

arquivo = pd.read_excel(r"C:\Users\L_SAR\Documents\Desenv\notas\tangua_nova_rl\Tangua_Nova_RL.xls")

#----------------------------------------------------MUDAR ORDEM DA DATA----------------------------------------------------

# Apagando linhas em branco:
arquivo = arquivo.dropna(subset = "Nota Fiscal")

# Convertendo campo Dia:
arquivo["Dia"] = arquivo["Dia"].apply(np.int64)

# Fazendo slice do campo competência para separar as partes:
mes_temp = arquivo["Competência"].str.slice(start = 6)
ano_temp = arquivo["Competência"].str.slice(start = 0, stop = 4)
barra_temp = arquivo["Competência"].str.slice(start = 4, stop = 5)

# Juntando as partes:
arquivo["Competência"] = (barra_temp) + (mes_temp) + (barra_temp) + (ano_temp)

#---------------------------------------------------------------------------------------------------------------------------

# Selecionando as colunas que serão utilizadas:
tangua_nova_rl = arquivo[["Nota Fiscal", "Dia", "Competência", "CPF/CNPJ - Tomador/Prestador", "Vr.NF"]]

# Criando campos adicionais:
tangua_nova_rl["Empresa"] = "Tanguá Nova RL"
tangua_nova_rl["Unidade"] = "Tanguá Nova RL"

# Renomeando os campos para o padrão:
tangua_nova_rl = tangua_nova_rl.rename(columns={"Nota Fiscal": "Nota"})
tangua_nova_rl = tangua_nova_rl.rename(columns={"CPF/CNPJ - Tomador/Prestador": "CNPJ_CPF_Tomador"})
tangua_nova_rl = tangua_nova_rl.rename(columns={"Vr.NF": "Valor"})

#----------------------------------------------------CRIANDO CAMPO DATA----------------------------------------------------

# Convertendo tipos de campos:
tangua_nova_rl["Dia"] = tangua_nova_rl["Dia"].astype(str)
tangua_nova_rl["Competência"] = tangua_nova_rl["Competência"].astype(str)

# Criando campo "Data"
tangua_nova_rl["Data"] = tangua_nova_rl["Dia"] + tangua_nova_rl["Competência"]

#---------------------------------------------------------------------------------------------------------------------------

# Reordenando colunas:
tangua_nova_rl = tangua_nova_rl[['Nota','Data', 'CNPJ_CPF_Tomador','Valor', 'Empresa', 'Unidade']]

# Convertendo tipos de campos:
tangua_nova_rl["Nota"] = tangua_nova_rl["Nota"].apply(np.int64) # Converte INT64
tangua_nova_rl["CNPJ_CPF_Tomador"] = tangua_nova_rl["CNPJ_CPF_Tomador"].astype(str)

# Valor total:
faturamento_tangua_nova_rl = tangua_nova_rl["Valor"].sum()

display(tangua_nova_rl)

print ("Total:", faturamento_tangua_nova_rl)

tangua_nova_rl.dtypes
# Out:
# C:\Users\L_SAR\AppData\Local\Temp\ipykernel_13500\1366292596.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tangua_nova_rl["Empresa"] = "Tanguá Nova RL"
# C:\Users\L_SAR\AppData\Local\Temp\ipykernel_13500\1366292596.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tangua_nova_rl["Unidade"] = "Tanguá Nova RL"
#       Nota       Data CNPJ_CPF_Tomador    Valor         Empresa  \
# 1    19310   4/7/2022     1457320703.0   202.26  Tanguá Nova RL
# ...

# %%
# Tanguá Transguard

arquivo = pd.read_excel(r"C:\Users\L_SAR\Documents\Desenv\notas\tangua_transguard\Tangua_Transguard.xls")  

#----------------------------------------------------MUDAR ORDEM DA DATA----------------------------------------------------

# Apagando linhas em branco:
arquivo = arquivo.dropna(subset = "Nota Fiscal")

# Convertendo campo Dia:
arquivo["Dia"] = arquivo["Dia"].apply(np.int64)

# Fazendo slice do campo competência para separar as partes:
mes_temp = arquivo["Competência"].str.slice(start = 6)
ano_temp = arquivo["Competência"].str.slice(start = 0, stop = 4)
barra_temp = arquivo["Competência"].str.slice(start = 4, stop = 5)

# Juntando as partes:
arquivo["Competência"] = (barra_temp) + (mes_temp) + (barra_temp) + (ano_temp)

#---------------------------------------------------------------------------------------------------------------------------

# Selecionando as colunas que serão utilizadas:
tangua_transguard = arquivo[["Nota Fiscal", "Dia", "Competência", "Nome do Tomador/Prestador", "CPF/CNPJ - Tomador/Prestador", "Vr.NF"]]

# Criando campos adicionais:
tangua_transguard["Empresa"] = "Tanguá Transguard"
tangua_transguard["Unidade"] = "Tanguá Transguard"

# Renomeando os campos para o padrão:
tangua_transguard = tangua_transguard.rename(columns={"Nota Fiscal": "Nota"})
tangua_transguard = tangua_transguard.rename(columns={"Nome do Tomador/Prestador": "Tomador"})
tangua_transguard = tangua_transguard.rename(columns={"CPF/CNPJ - Tomador/Prestador": "CNPJ_CPF_Tomador"})
tangua_transguard = tangua_transguard.rename(columns={"Vr.NF": "Valor"})

#----------------------------------------------------CRIANDO CAMPO DATA----------------------------------------------------

# Convertendo tipos de campos:
tangua_transguard["Dia"] = tangua_transguard["Dia"].astype(str)
tangua_transguard["Competência"] = tangua_transguard["Competência"].astype(str)

# Criando campo "Data"
tangua_transguard["Data"] = tangua_transguard["Dia"] + tangua_transguard["Competência"]

#---------------------------------------------------------------------------------------------------------------------------

# Reordenando colunas:
tangua_transguard = tangua_transguard[['Nota','Data','Tomador','CNPJ_CPF_Tomador','Valor', 'Empresa', 'Unidade']]

# Convertendo tipos de campos:
tangua_transguard["Nota"] = tangua_transguard["Nota"].apply(np.int64) # Converte INT64
tangua_transguard["CNPJ_CPF_Tomador"] = tangua_transguard["CNPJ_CPF_Tomador"].astype(str)

# Valor total:
faturamento_tangua_transguard = tangua_transguard["Valor"].sum()

display(tangua_transguard)

print ("Total:", faturamento_tangua_transguard)

tangua_transguard.dtypes
# Out:
# C:\Users\L_SAR\AppData\Local\Temp\ipykernel_13500\322472443.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tangua_transguard["Empresa"] = "Tanguá Transguard"
# C:\Users\L_SAR\AppData\Local\Temp\ipykernel_13500\322472443.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tangua_transguard["Unidade"] = "Tanguá Transguard"
#     Nota       Data                           Tomador CNPJ_CPF_Tomador  \
# 0    145   1/7/2022         MATHEUS DE OLIVEIRA SILVA    15345245762.0
# ...

# %%
# Teixeira de Freitas Transguard Nordeste

arquivo = pd.read_excel(r"C:\Users\L_SAR\Documents\Desenv\notas\teixeira_de_freitas_transguard_nordeste\Teixeira_de_freitas_Transguard_Nordeste.xlsx")  

# Selecionando as colunas que serão utilizadas:
teixeira_de_freitas_trans = arquivo[["ns1:Numero", "ns1:DataEmissao", "ns1:RazaoSocial17", "ns1:Cpf", "ns1:ValorServicos", "ns1:RazaoSocial"]]

# Apagando linhas em branco:
teixeira_de_freitas_trans = teixeira_de_freitas_trans.dropna(subset=['ns1:Numero'])

# Criando campos adicionais:
teixeira_de_freitas_trans["Unidade"] = "Teixeira de Freitas Transguard Nordeste"

# Renomeando os campos para o padrão:
teixeira_de_freitas_trans = teixeira_de_freitas_trans.rename(columns={"ns1:Numero": "Nota"})
teixeira_de_freitas_trans = teixeira_de_freitas_trans.rename(columns={"ns1:DataEmissao": "Data"})
teixeira_de_freitas_trans = teixeira_de_freitas_trans.rename(columns={"ns1:RazaoSocial17": "Tomador"})
teixeira_de_freitas_trans = teixeira_de_freitas_trans.rename(columns={"ns1:Cpf": "CNPJ_CPF_Tomador"})
teixeira_de_freitas_trans = teixeira_de_freitas_trans.rename(columns={"ns1:ValorServicos": "Valor"})
teixeira_de_freitas_trans = teixeira_de_freitas_trans.rename(columns={"ns1:RazaoSocial": "Empresa"})

# Reordenando colunas:
teixeira_de_freitas_trans = teixeira_de_freitas_trans[['Nota','Data','Tomador','CNPJ_CPF_Tomador','Valor', 'Empresa', 'Unidade']]

# Convertendo tipos de campos:
teixeira_de_freitas_trans["Nota"] = teixeira_de_freitas_trans["Nota"].apply(np.int64) # Converte INT64
teixeira_de_freitas_trans["Data"] = teixeira_de_freitas_trans["Data"].astype(str)
teixeira_de_freitas_trans["CNPJ_CPF_Tomador"] = teixeira_de_freitas_trans["CNPJ_CPF_Tomador"].astype(str)

# Valor total:
faturamento_teixeira_de_freitas_trans = teixeira_de_freitas_trans["Valor"].sum()

#display(teixeira_de_freitas_trans)

print ("Total:", faturamento_teixeira_de_freitas_trans)

teixeira_de_freitas_trans.dtypes
# Out:
# Total: 61540.38
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# Três Rios - Nova RL

arquivo = pd.read_excel(r"C:\Users\L_SAR\Documents\Desenv\notas\tres_rios_nova_rl\Tres Rios - Nova RL.xlsx")  

#----------------------------------------------------SEPARAR CPF E TOMADOR----------------------------------------------------

# Apagando linhas em branco:
arquivo = arquivo.dropna(subset = "NF")

# Fazendo slice do campo tomador para compor o campo CPF:
tomador_temp = arquivo["Tomador"].str.slice(start = 17)
cpf_temp = arquivo["Tomador"].str.slice(start = 0, stop = 14)

# Criando campos para separar os dados:
arquivo["Tomador"] = (tomador_temp)
arquivo["CNPJ_CPF_Tomador"] = (cpf_temp)

#-----------------------------------------------------------------------------------------------------------------------------

# Selecionando as colunas que serão utilizadas:
tres_rios_nova_rl = arquivo[["NF", "Dt.Emissão", "Tomador", "CNPJ_CPF_Tomador", "Valor", "Execução"]]

# Apagando linhas em branco:
tres_rios_nova_rl = tres_rios_nova_rl.dropna(subset=['NF'])

# Criando campos adicionais:
tres_rios_nova_rl["Empresa"] = "Três Rios - Nova RL"
    
# Renomeando os campos para o padrão:
tres_rios_nova_rl = tres_rios_nova_rl.rename(columns={"NF": "Nota"})
tres_rios_nova_rl = tres_rios_nova_rl.rename(columns={"Dt.Emissão": "Data"})
tres_rios_nova_rl = tres_rios_nova_rl.rename(columns={"Tomador": "Tomador"})
tres_rios_nova_rl = tres_rios_nova_rl.rename(columns={"CNPJ_CPF_Tomador": "CNPJ_CPF_Tomador"})
tres_rios_nova_rl = tres_rios_nova_rl.rename(columns={"Valor": "Valor"})
tres_rios_nova_rl = tres_rios_nova_rl.rename(columns={"Execução": "Unidade"})

# Reordenando colunas:
tres_rios_nova_rl = tres_rios_nova_rl[['Nota', 'Data', 'Tomador', 'CNPJ_CPF_Tomador', 'Valor', 'Empresa', 'Unidade']]

# Convertendo tipos de campos:
#tres_rios_nova_rl[""] = tres_rios_nova_rl[""].apply(np.int64) # Converte INT64
tres_rios_nova_rl["Data"] = tres_rios_nova_rl["Data"].astype(str)

# Valor total:
faturamento_tres_rios_nova_rl = tres_rios_nova_rl["Valor"].sum()

#display(tres_rios_nova_rl)

print ("Total:", faturamento_tres_rios_nova_rl)

tres_rios_nova_rl.dtypes
# Out:
# Total: 24655.21
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
# Três Rios - Transguard

arquivo = pd.read_excel(r"C:\Users\L_SAR\Documents\Desenv\notas\tres_rios_transguard\Tres Rios - Transguard.xlsx")  

#----------------------------------------------------SEPARAR CPF E TOMADOR----------------------------------------------------

# Apagando linhas em branco:
arquivo = arquivo.dropna(subset = "NF")

# Fazendo slice do campo tomador para compor o campo CPF:
tomador_temp = arquivo["Tomador"].str.slice(start = 17)
cpf_temp = arquivo["Tomador"].str.slice(start = 0, stop = 14)

# Criando campos para separar os dados:
arquivo["Tomador"] = (tomador_temp)
arquivo["CNPJ_CPF_Tomador"] = (cpf_temp)

#-----------------------------------------------------------------------------------------------------------------------------

# Selecionando as colunas que serão utilizadas:
tres_rios_nova_trans = arquivo[["NF", "Dt.Emissão", "Tomador", "CNPJ_CPF_Tomador", "Valor", "Execução"]]

# Apagando linhas em branco:
tres_rios_nova_trans = tres_rios_nova_trans.dropna(subset=['NF'])

# Criando campos adicionais:
tres_rios_nova_trans["Empresa"] = "Três Rios - Transguard"
    

# Renomeando os campos para o padrão:
tres_rios_nova_trans = tres_rios_nova_trans.rename(columns={"NF": "Nota"})
tres_rios_nova_trans = tres_rios_nova_trans.rename(columns={"Dt.Emissão": "Data"})
tres_rios_nova_trans = tres_rios_nova_trans.rename(columns={"Tomador": "Tomador"})
tres_rios_nova_trans = tres_rios_nova_trans.rename(columns={"CNPJ_CPF_Tomador": "CNPJ_CPF_Tomador"})
tres_rios_nova_trans = tres_rios_nova_trans.rename(columns={"Valor": "Valor"})
tres_rios_nova_trans = tres_rios_nova_trans.rename(columns={"Execução": "Unidade"})

# Reordenando colunas:
tres_rios_nova_trans = tres_rios_nova_trans[['Nota','Data','Tomador','CNPJ_CPF_Tomador','Valor', 'Empresa', 'Unidade']]

# Convertendo tipos de campos:
#tres_rios_nova_trans[""] = tres_rios_nova_trans[""].apply(np.int64) # Converte INT64
tres_rios_nova_trans["Data"] = tres_rios_nova_trans["Data"].astype(str)

# Valor total:
faturamento_tres_rios_nova_trans = tres_rios_nova_trans["Valor"].sum()

#display(tres_rios_nova_trans)

print ("Total:", faturamento_tres_rios_nova_trans)

tres_rios_nova_trans.dtypes
# Out:
# Total: 19313.839999999997
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %% [markdown]
# # Merge das prefeituras:

# %%
# Barra do Piraí Transguard + Caicó Transguard:

df_merge = pd.merge(barra_pirai, caico, how = 'outer')

# %%
# + Caruaru Transguard

df_merge = pd.merge(df_merge, caruaru, how = 'outer')

# %%
# + Ceilândia Transguard

df_merge = pd.merge(df_merge, ceilandia, how = 'outer')

# %%
# + Coité SPE

df_merge = pd.merge(df_merge, coite, how = 'outer')

# %%
# + Cuiabá Nova

df_merge = pd.merge(df_merge, cuiaba, how = 'outer')

# %%
# + Itabuna Transguarde Nordeste

df_merge = pd.merge(df_merge, itabuna, how = 'outer')

# %%
# + Itaguaí Transguard

df_merge = pd.merge(df_merge, itaguai_trans, how = 'outer')

# %%
# + Itaperuna Nova RL

df_merge = pd.merge(df_merge, itaperuna_nova_rl, how = 'outer')

# %%
# + Maceió Transguard

df_merge = pd.merge(df_merge, maceio_trans, how = 'outer')

# %%
# + Magé Nova RL

df_merge = pd.merge(df_merge, mage_nova_rl, how = 'outer')

# %%
# + Magé Transguard

df_merge = pd.merge(df_merge, mage_transguard, how = 'outer')

# %%
# + Mossoró Transguard

df_merge = pd.merge(df_merge, mossoro_trans, how = 'outer')

# %%
# + Natal Transguard

df_merge = pd.merge(df_merge, natal_trans, how = 'outer')

# %%
# + Petrolina RL

df_merge = pd.merge(df_merge, petrolina_rl, how = 'outer')

# %%
# + Salgueiro Transguard

df_merge = pd.merge(df_merge, salgueiro_trans, how = 'outer')

# %%
# + São Caetano Nova RL

df_merge = pd.merge(df_merge, sao_caetano_nova_rl, how = 'outer')

# %%
# + São Gonçalo Transguard

df_merge = pd.merge(df_merge, sao_goncalo_trans, how = 'outer')

# %%
# + Senhor do Bonfim

df_merge = pd.merge(df_merge, senhor_do_bonfim, how = 'outer')

# %%
# + Serra Talhada

df_merge = pd.merge(df_merge, serra_talhada, how = 'outer')

# %%
# + Tanguá Nova RL

df_merge = pd.merge(df_merge, tangua_nova_rl, how = 'outer')

# %%
# + Tanguá Transguard

df_merge = pd.merge(df_merge, tangua_transguard, how = 'outer')

# %%
# + Teixeira de Freitas Transguard

df_merge = pd.merge(df_merge, teixeira_de_freitas_trans, how = 'outer')

# %%
# + Três Rios Nova RL

df_merge = pd.merge(df_merge, tres_rios_nova_rl, how = 'outer')

# %%
# + Três Rios Transguard

df_merge = pd.merge(df_merge, tres_rios_nova_trans, how = 'outer')

# %%
# Valor total prefeituras:
faturamento_df_merge = df_merge["Valor"].sum()

print ("Total:", faturamento_df_merge)

df_merge.dtypes
# Out:
# Total: 1240007.2
# Nota                  int64
# Data                 object
# Tomador              object
# CNPJ_CPF_Tomador     object
# Valor               float64
# Empresa              object
# Unidade              object
# dtype: object

# %%
filename = r'C:\Users\L_SAR\Documents\Desenv\notas\prefeituras.xlsx'
df_merge.to_excel(filename, sheet_name='merged', index=False)

# %% [markdown]
# # Base vs Prefeituras:

# %%
dif = base_sistema.merge(df_merge, on=['Nota', 'Unidade'], how='outer', suffixes=['', '_'], indicator=True)
display(dif)
# Out:
#        Nota        Data                                            Tomador  \
# 0     16385  01/07/2022  MARIA CLARA ROSENO DA SILVA (113523)          ...
# 1     16386  01/07/2022  MARIA CLARA ROSENO DA SILVA (113523)          ...
# 2     16387  01/07/2022  SANDRA GOMES DE ANDRADE PROTASIO (113530)     ...
# 3     16388  01/07/2022  SANDRA GOMES DE ANDRADE PROTASIO (113530)     ...
# 4     16391  04/07/2022  JOSE IBIS TORRES (114087)                     ...
# ...     ...         ...                                                ...
# 9424    168         NaN                                                NaN
# 9425    169         NaN                                                NaN
# 9426    170         NaN                                                NaN
# 9427    171         NaN                                                NaN
# 9428    172         NaN                                                NaN
#
#         CNPJ_CPF_Tomador   Valor  \
# ...

# %%
# Indexando:
apaga_ambos = dif[ dif['_merge'] == 'right_only' ].index
apaga_left = dif[ dif['_merge'] == 'left_only' ].index

# Apagar essas linhas do Dataframe:
dif.drop(apaga_ambos, inplace = True)
dif.drop(apaga_left, inplace = True)

display(dif)
# Out:
# Empty DataFrame
# Columns: [Nota, Data, Tomador, CNPJ_CPF_Tomador, Valor, Empresa, Unidade, Data_, Tomador_, CNPJ_CPF_Tomador_, Valor_, Empresa_, _merge]
# Index: []

# %%
# Valor total prefeituras:
faturamento_dif = dif["Valor_"].sum()

print ("Total:", faturamento_dif)

dif.dtypes
# Out:
# Total: 0.0
# Nota                    int64
# Data                   object
# Tomador                object
# CNPJ_CPF_Tomador       object
# Valor                 float64
# Empresa                object
# Unidade                object
# Data_                  object
# Tomador_               object
# CNPJ_CPF_Tomador_      object
# Valor_                float64
# Empresa_               object
# _merge               category
# dtype: object
